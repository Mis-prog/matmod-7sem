# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('../result/task2/full_trajectory.csv',sep=' ')

# %%
# plt.scatter(0,0,color='red',label='Планета')
plt.plot(data.x,data.y,label='Ракета')
plt.plot(data.x3,data.y3,label='Спутник')
# plt.xlim(-1e7,1.3e7)
# plt.ylim(-1.3e7,1e7)
plt.legend()
plt.grid()
