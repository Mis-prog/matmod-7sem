# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('../result/task2/full_trajectory.csv',sep=' ')

# %%
x=-50368219856.43
y=-219503615669.65
plt.scatter(0,0,color='red',label='Марс')
plt.plot(data.x-x,data.y-y,label='Ракета')
plt.plot(data.x3-x,data.y3-y,label='Фобос')
plt.grid()
plt.legend()
