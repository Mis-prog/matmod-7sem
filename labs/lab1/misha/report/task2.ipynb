# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# # Задание 2

# %%
path=f'../result/task2/full_trajectory_mt-2.06_angle-4.00.csv'
data=pd.read_csv(path,sep=' ')
data_last=data.iloc[-1]

# %%
plt.scatter(-50368219856.43,-219503615669.65,color='red',label='Марс')
plt.scatter(data_last.x3,data_last.y3,color='blue')
plt.scatter(data_last.x,data_last.y,color='green')
plt.plot(data.x3,data.y3,label='Фобос',color='blue')
plt.plot(data.x,data.y,label='Ракета',color='green')
# plt.xlim(-63051822463.82-1e7,-63051822463.82+1e7)
# plt.ylim(141005424242.41-1e7,141005424242.41+1e7)
plt.legend(loc='best')
plt.grid()

# %%
import numpy as np
planeta=[-50368219856.43,-219503615669.65]
spytnik=[ -50370393498.29, -219513089385.80]

# %%
dist=np.sqrt((planeta[0]-spytnik[0])**2+(planeta[1]-spytnik[1])**2)
dist
# Out:
# np.float64(9719877.39769397)
