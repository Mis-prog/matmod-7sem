# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# # Задание 2

# %%
path=f'../result/task2/full_trajectory_mt-3.33_angle-180.00.csv'
data=pd.read_csv(path,sep=' ')[:400000]
data_last=data.iloc[-1]

# %%
plt.scatter(-50368219856.43,-219503615669.65,color='red',label='Земля')
plt.scatter(data_last.x3,data_last.y3,color='blue')
plt.scatter(data_last.x,data_last.y,color='green')
plt.plot(data.x3,data.y3,label='Луна',color='blue')
plt.plot(data.x,data.y,label='Ракета',color='green')
# plt.xlim(-63051822463.82-1e7,-63051822463.82+1e7)
# plt.ylim(141005424242.41-1e7,141005424242.41+1e7)
plt.legend(loc='best')
plt.grid()
