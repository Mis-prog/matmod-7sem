# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Задание 1

# %%
data_trajectory=pd.read_csv('../res_task1/path_full.csv',sep=' ')
# data_trajectory=data_trajectory[:2]

# %%
plt.plot(data_trajectory.x2,data_trajectory.y2,label='Планета')
plt.plot(data_trajectory.x3,data_trajectory.y3,label='Cпутник')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# # Задание 2

# %%
coord=[[3414408.65,-225838531428.76], [6864231.82, -225843785989.04]]

# %%
import math
x_coords, y_coords = zip(*coord)
math.sqrt((x_coords[0]-x_coords[1])**2+(y_coords[0]-y_coords[1])**2)
# Out:
# 6285831.976787934

# %%
6000e3
# Out:
# 6000000.0

# %%
coord=[[-45779049843.29, -220565040943.48],[-45779234115.16 ,-220575669506.13]]
x_coords, y_coords = zip(*coord)
math.sqrt((x_coords[0]-x_coords[1])**2+(y_coords[0]-y_coords[1])**2)
# Out:
# 10630159.929508097

# %%
# plt.scatter(0,0,color='red')
plt.scatter(x_coords,y_coords)
# plt.scatter(-24158620.87, 225838185199.02,color='red',label='Марс')

# %%
data_trajectory_raketa=pd.read_csv('../res_task2/full_trajectory.csv',sep=' ')
data_trajectory_raketa
# Out:
#                    x             y            x3            y3
# 0      -4.578260e+10 -2.205650e+11 -4.577920e+10 -2.205760e+11
# 1      -4.578260e+10 -2.205650e+11 -4.577920e+10 -2.205760e+11
# 2      -4.578260e+10 -2.205650e+11 -4.577920e+10 -2.205760e+11
# 3      -4.578260e+10 -2.205650e+11 -4.577920e+10 -2.205760e+11
# 4      -4.578260e+10 -2.205650e+11 -4.577920e+10 -2.205760e+11
# ...              ...           ...           ...           ...
# 863996 -4.542010e+10 -2.209160e+11 -4.578870e+10 -2.205480e+11
# 863997 -4.542010e+10 -2.209160e+11 -4.578870e+10 -2.205480e+11
# 863998 -4.542010e+10 -2.209160e+11 -4.578870e+10 -2.205480e+11
# 863999 -4.542010e+10 -2.209160e+11 -4.578870e+10 -2.205480e+11
# 864000 -4.542010e+10 -2.209160e+11 -4.578870e+10 -2.205480e+11
#
# [864001 rows x 4 columns]

# %%
end = 5000000
plt.scatter(-45779049843.29,-220565040943.48,color='red',label='Марс')
# plt.plot(data_trajectory_raketa.x[:end],data_trajectory_raketa.y[:end],label='Ракета',color='orange')
plt.plot(data_trajectory_raketa.x3[:end],data_trajectory_raketa.y3[:end],label='Фобос',color='green')
plt.legend(loc='best')
plt.grid()
plt.legend()

# %%
def thousandth_branch_drawe():
    spytnik = pd.read_csv('../res_task1/path_spytnik_3.csv', sep=' ')
    planeta = pd.read_csv('../res_task1/path_planeta_3.csv',sep=' ')
    plt.plot(spytnik.x, spytnik.y, label='Фобос')
    plt.plot(planeta.x, planeta.y, label='Марс')
    plt.legend()
    plt.show()

# %%
thousandth_branch_drawe()
