# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('../result/task1/path_full.csv',sep=' ')
data
# Out:
#                 x2            y2            x3            y3
# 0     1.507030e+11  1.500000e+08  1.510950e+11  1.550000e+08
# 1     1.507020e+11  3.000000e+08  1.510940e+11  3.099990e+08
# 2     1.507020e+11  4.499990e+08  1.510940e+11  4.649960e+08
# 3     1.507020e+11  5.999990e+08  1.510930e+11  6.199900e+08
# 4     1.507010e+11  7.499970e+08  1.510920e+11  7.749800e+08
# ...            ...           ...           ...           ...
# 6303  1.467340e+11 -3.467600e+10  1.467840e+11 -3.504700e+10
# 6304  1.467680e+11 -3.452990e+10  1.468230e+11 -3.490030e+10
# 6305  1.468010e+11 -3.438370e+10  1.468620e+11 -3.475350e+10
# 6306  1.468350e+11 -3.423750e+10  1.469010e+11 -3.460660e+10
# 6307  1.468680e+11 -3.409130e+10  1.469390e+11 -3.445960e+10
#
# [6308 rows x 4 columns]

# %%
plt.plot(data.x2,data.y2,label='Земля')
plt.plot(data.x3,data.y3,label='Луна')
plt.grid()
plt.legend()
