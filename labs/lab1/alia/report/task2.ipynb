# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# # Задание 2

# %%
data=pd.read_csv('../result/task2/full_trajectory.csv',sep=' ')
data
# Out:
#                    x             y            x3            y3
# 0      -6.305450e+10  1.410120e+11 -6.319880e+10  1.413340e+11
# 1      -6.305460e+10  1.410110e+11 -6.319880e+10  1.413340e+11
# 2      -6.305460e+10  1.410110e+11 -6.319880e+10  1.413340e+11
# 3      -6.305470e+10  1.410110e+11 -6.319880e+10  1.413340e+11
# 4      -6.305470e+10  1.410110e+11 -6.319880e+10  1.413340e+11
# ...              ...           ...           ...           ...
# 241969 -6.266060e+10  1.410570e+11 -6.265900e+10  1.410560e+11
# 241970 -6.266060e+10  1.410570e+11 -6.265900e+10  1.410560e+11
# 241971 -6.266060e+10  1.410570e+11 -6.265900e+10  1.410560e+11
# 241972 -6.266060e+10  1.410570e+11 -6.265900e+10  1.410560e+11
# 241973 -6.266060e+10  1.410570e+11 -6.265900e+10  1.410560e+11
#
# [241974 rows x 4 columns]

# %%
plt.scatter(-63051822463.82,141005424242.41,color='red',label='Земля')
plt.plot(data.x3,data.y3,label='Луна',color='blue')
plt.plot(data.x,data.y,label='Ракета',color='green')
plt.legend(loc='best')
plt.grid()
