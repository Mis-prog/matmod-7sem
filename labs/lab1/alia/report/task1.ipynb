# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Задание 1

# %%
data=pd.read_csv('../result/task1/path_full.csv',sep=' ')

# %%
data_start=data[:300]

# %%
plt.plot(data_start.x2,data_start.y2,label='Земля')
plt.plot(data_start.x3,data_start.y3,label='Луна')
plt.title('Начало вращения')
plt.grid()
plt.legend()

# %%
plt.plot(data.x2,data.y2,label='Земля')
plt.plot(data.x3,data.y3,label='Луна')
plt.title('1000 оборотов')
plt.grid()
plt.legend()

# %%
data_planeta_0=pd.read_csv('../result/task1/path_planeta_0.csv',sep=' ')
data_planeta_1=pd.read_csv('../result/task1/path_planeta_1.csv',sep=' ')
data_planeta_2=pd.read_csv('../result/task1/path_planeta_2.csv',sep=' ')
data_planeta_3=pd.read_csv('../result/task1/path_planeta_3.csv',sep=' ')

# %%
plt.title('Земля')
plt.plot(data_planeta_0.x,data_planeta_0.y,label='1')
plt.plot(data_planeta_1.x,data_planeta_1.y,label='100')
plt.plot(data_planeta_2.x,data_planeta_2.y,label='500')
plt.plot(data_planeta_3.x,data_planeta_3.y,label='1000')
plt.xlim(1.084e11, 1.085e11)  
plt.ylim(1.057e11, 1.058e11) 
plt.legend()
plt.grid()

# %%
data_spytnik_0=pd.read_csv('../result/task1/path_spytnik_0.csv',sep=' ')
data_spytnik_1=pd.read_csv('../result/task1/path_spytnik_1.csv',sep=' ')
data_spytnik_2=pd.read_csv('../result/task1/path_spytnik_2.csv',sep=' ')
data_spytnik_3=pd.read_csv('../result/task1/path_spytnik_3.csv',sep=' ')

# %%
plt.title('Луна')
plt.plot(data_spytnik_0.x,data_spytnik_0.y,label='1')
plt.plot(data_spytnik_1.x,data_spytnik_1.y,label='100')
plt.plot(data_spytnik_2.x,data_spytnik_2.y,label='500')
plt.plot(data_spytnik_3.x,data_spytnik_3.y,label='1000')
plt.xlim(1.06e11, 1.1e11)  
plt.ylim(1.057e11, 1.058e11) 
plt.legend()
plt.grid()

# %% [markdown]
# # Задание 2
